# %%
import pandas as pd

# %%
data_loc = "../data/XWines_Slim_1K_wines.csv"

# %%
df = pd.read_csv(data_loc)
df['WineName'].unique()
# Out:
# array(['Espumante Moscatel', 'Ancellotta', 'Cabernet Sauvignon',
#        'Maison de Ville Cabernet-Merlot', 'Do Lugar Moscatel Espumantes',
#        'Paradoxo Cabernet Sauvignon', 'Defesa Tinto',
#        'Vinho Verde Branco', 'Ruby Port', 'Tawny Port',
#        'Acquasantiera Tinto Seco Fino',
#        'Colheita Tardia Malvasia-Moscato', 'Cave Cabernet Sauvignon',
#        'Singular Nebbiolo', 'Merlot Reserva', 'Malbec Brut Rosé',
#        'Espumante Método Charmat Brut', 'Vista de Serra Syrah',
#        'Cuvée Giuseppe Merlot-Cabernet Sauvignon', 'Reserva Tannat',
#        'Millesimé Cabernet Sauvignon', 'Brut Prosecco', 'Moscatel',
#        'Origem Merlot', 'Quinta do Seival Estate Castas Portuguesas',
#        'Réserve Brut', 'Sur Lie Nature', 'Agnus Cabernet Sauvignon',
#        'Selecão Chardonnay-Viognier', 'Aquarela Moscatel Espumante',
#        'Nature', 'Terranova Espumante Moscatel',
#        'Colheita Tardia Malvasia Bianca', 'Primeira Estrada Syrah',
# ...

# %%
df[df['WineName'] == 'Malbec']
# Out:
#      WineID WineName Type      Elaborate      Grapes  \
# 246  111907   Malbec  Red  Varietal/100%  ['Malbec']
# 636  167418   Malbec  Red  Varietal/100%  ['Malbec']
# 637  167419   Malbec  Red  Varietal/100%  ['Malbec']
# 638  167425   Malbec  Red  Varietal/100%  ['Malbec']
# 639  167429   Malbec  Red  Varietal/100%  ['Malbec']
# 645  167445   Malbec  Red  Varietal/100%  ['Malbec']
# 647  167449   Malbec  Red  Varietal/100%  ['Malbec']
# 664  168002   Malbec  Red  Varietal/100%  ['Malbec']
#
#                        Harmonize   ABV              Body Acidity Code  \
# 246  ['Beef', 'Lamb', 'Poultry']  13.5  Very full-bodied    High   AR
# 636  ['Beef', 'Lamb', 'Poultry']  13.5  Very full-bodied    High   AR
# 637  ['Beef', 'Lamb', 'Poultry']  13.5  Very full-bodied    High   AR
# 638  ['Beef', 'Lamb', 'Poultry']  13.9  Very full-bodied    High   AR
# 639  ['Beef', 'Lamb', 'Poultry']  14.5  Very full-bodied    High   AR
# ...
